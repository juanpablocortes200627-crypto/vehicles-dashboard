# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../vehicles_us.csv')

df.head()
# Out:
# Running cells with 'vehicles_env (3.13.2) (Python 3.13.2)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/Juan Pablo/Documents/GitHub/vehicles-dashboard/vehicles_env/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
px.histogram(df, x="odometer")

# %%
px.scatter(df, x="odometer", y="price")
